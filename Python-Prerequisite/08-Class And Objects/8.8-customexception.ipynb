# %% [markdown]
# ### Custom exception (Raise and Throw an exception)

# %%
class Error(Exception):
    def __init__(self, *args):
        super().__init__(*args)

class dobException(Error):
    def __init__(self, *args):
        super().__init__(*args)

# %%
year=int(input("Enter the dob"))
age=2024-year

if age<=30 and age>=20:
    print("The age is valid so you can apply for the exam")
else:
    raise dobException
# Out:
# The age is valid so you can apply for the exam

# %%
year=int(input("Enter the dob"))
age=2024-year

if age<=30 and age>=20:
    print("The age is valid so you can apply for the exam")
else:
    raise dobException
# Out:
# ---------------------------------------------------------------------------
# dobException                              Traceback (most recent call last)
# Cell In[13], line 7
#       5     print("The age is valid so you can apply for the exam")
#       6 else:
# ----> 7     raise dobException
#
# dobException:

# %%
class Error(Exception):
    pass

class dobException(Error):
    pass

# %%
year=int(input("Enter the dob"))
age=2024-year

try:
    if age<=30 and age>=20:
        print("The age is valid so you can apply for the exam")
    else:
        raise dobException
except dobException:
    print("Sorry,your age should be greater than 20 or less than 30")
# Out:
# Sorry,your age should be greater than 20 or less than 30
