# %% [markdown]
# # Module 5: Modules and Packages Assignments
# ## Lesson 5.1: Importing Modules
# ### Assignment 1: Importing and Using Modules
#
# Import the `math` module and use it to calculate the square root of 25 and the sine of 90 degrees.

# %%
import math
number = int(input("Enter a number: "))
sqrt = math.sqrt(number)
print(f"The square root of {number} is {sqrt}")
# Out:
# The square root of 12 is 3.4641016151377544

# %% [markdown]
# ### Assignment 2: Aliasing Modules
#
# Import the `datetime` module with an alias and use it to print the current date and time.

# %%
import datetime as dt
now = dt.datetime.now()
print(f"Current date and time: {now}")
# Out:
# Current date and time: 2026-01-30 22:34:41.305498

# %% [markdown]
# ### Assignment 3: Importing Specific Functions
#
# Import the `randint` function from the `random` module and use it to generate a random integer between 1 and 100.

# %%
from random import randint
random_number = randint(1, 100)
print(f"Random number between 1 and 100: {random_number}")
# Out:
# Random number between 1 and 100: 59

# %% [markdown]
# ### Assignment 4: Importing Multiple Functions
#
# Import the `sqrt` and `pow` functions from the `math` module and use them to calculate the square root of 16 and 2 raised to the power of 3.

# %%
from math import sqrt, pow
square_root = sqrt(16)
power = pow(2, 3)

print(f"Square root of 16 is {square_root}")
print(f"2 raised to the power of 3 is {power}")
# Out:
# Square root of 16 is 4.0
# 2 raised to the power of 3 is 8.0

# %% [markdown]
# ### Assignment 5: Handling Import Errors
#
# Write code that attempts to import a non-existent module and gracefully handles the import error by printing an error message.

# %%
# try:
    # import non_existent_module
# except ImportError:
    # print("Error: The module does")

# %% [markdown]
# ## Lesson 5.2: Standard Library Overview
# ### Assignment 6: Working with the `os` Module
#
# Use the `os` module to create a new directory, list the contents of the current directory, and remove the newly created directory.

# %%
import os
current_directory = os.getcwd()
print(f"Current working directory: {current_directory}")

os.mkdir("new_directory")
print("new_directory created")
print(os.listdir("."))

os.rmdir("new_directory")
print("new_directory removed")
print(os.listdir("."))
# Out:
# Current working directory: d:\GitHub\MLOps-Bootcamp\Python-Prerequisite\05-Modules
# new_directory created
# ['5.1-import.ipynb', '5.2-Standardlibrary.ipynb', 'destination.txt', 'example.csv', 'mypackage', 'new_directory', 'package', 'packagesquestion.ipynb', 'source.txt', 'test.py', 'test_dir']
# new_directory removed
# ['5.1-import.ipynb', '5.2-Standardlibrary.ipynb', 'destination.txt', 'example.csv', 'mypackage', 'package', 'packagesquestion.ipynb', 'source.txt', 'test.py', 'test_dir']

# %% [markdown]
# ### Assignment 7: Working with the `sys` Module
#
# Use the `sys` module to print the Python version currently in use and the command-line arguments passed to the script.

# %%
import sys
print(f"Python version: {sys.version}")
# Out:
# Python version: 3.12.0 | packaged by Anaconda, Inc. | (main, Oct  2 2023, 17:20:38) [MSC v.1916 64 bit (AMD64)]

# %% [markdown]
# ### Assignment 8: Working with the `math` Module
#
# Use the `math` module to calculate the greatest common divisor (GCD) of two numbers and the factorial of a number.

# %%
import math

gcd = math.gcd(48, 18)
print(f"GCD of 48 and 18 is {gcd}")

factorial = math.factorial(5)
print(f"Factorial of 5 is {factorial}")
# Out:
# GCD of 48 and 18 is 6
# Factorial of 5 is 120

# %% [markdown]
# ### Assignment 9: Working with the `datetime` Module
#
# Use the `datetime` module to print the current date, calculate the date 100 days from today, and determine the day of the week for a given date.

# %%
import datetime as dt
now = dt.datetime.now()

print(f"Current date and time: {now}")

hundred_days_later = now + dt.timedelta(days=100)
print(f"Date and time after 100 days: {hundred_days_later}")
# Out:
# Current date and time: 2026-01-30 22:35:23.205218
# Date and time after 100 days: 2026-05-10 22:35:23.205218

# %% [markdown]
# ### Assignment 10: Working with the `random` Module
#
# Use the `random` module to generate a list of 5 random numbers between 1 and 50 and shuffle the elements of a list.

# %%
from random import randint
list_of_numbers = [randint(1, 100) for _ in range(5)]
print(f"List of 5 random numbers between 1 and 100: {list_of_numbers}")
# Out:
# List of 5 random numbers between 1 and 100: [76, 94, 6, 43, 24]

# %% [markdown]
# ## Lesson 5.3: Creating and Using Packages
# ### Assignment 11: Creating a Simple Package
#
# Create a package named `mypackage` with two modules: `module1` and `module2`. `module1` should contain a function that adds two numbers, and `module2` should contain a function that multiplies two numbers. Write code to use these functions.

# %%
import os
os.mkdir("mypackage")
os.chdir("mypackage")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[11], line 2
#       1 import os
# ----> 2 os.mkdir("mypackage")
#       3 os.chdir("mypackage")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'mypackage'

# %% [markdown]
# ### Assignment 12: Using `__init__.py`
#
# Modify the `mypackage` package to include an `__init__.py` file that imports the functions from `module1` and `module2`. Write code to use these functions.

# %%
# Create an empty Python file named 'module1.py'
with open("__init__.py", "w") as file:
    file.write("'''__init__.py is a special file used in \
               Python to definepackages and initialize their namespaces'''")

# Create an empty Python file named 'module1.py'
with open("module1.py", "w") as file:
    pass
# Create an empty Python file named 'module2.py'
with open("module2.py", "w") as file:
    pass

# %% [markdown]
# ### Assignment 13: Importing from a Package
#
# Write code to import and use the functions from `mypackage` without explicitly importing `module1` and `module2`.

# %%
from mypackage import module1, module2
print(module1.addition(5, 3))
print(module2.multiplication(4, 2))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 2
#       1 from mypackage import module1, module2
# ----> 2 print(module1.addition(5, 3))
#       3 print(module2.multiplication(4, 2))
#
# AttributeError: module 'mypackage.module1' has no attribute 'addition'

# %% [markdown]
# ### Assignment 14: Relative Imports
#
# Create a subpackage named `subpackage` within `mypackage` and move `module2` into `subpackage`. Modify the import statements in `__init__.py` to use relative imports. Write code to use the functions from both modules.

# %%
current_directory = os.getcwd()
print(f"Current working directory: {current_directory}")

os.mkdir("subpackage")
os.chdir("subpackage")

with open("__init__.py", "w") as file:
     file.write("'''__init__.py is a special file used in \
               Python to definepackages and initialize their namespaces'''")

with open("module3.py", "w") as f:
    pass
# Out:
# Current working directory: d:\GitHub\MLOps-Bootcamp\Python-Prerequisite\05-Modules\subpackage

# %%
from mypackage.subpackage import module3
module3.division(10, 4)
# Out:
# 2.5

# %%
os.chdir("..")
os.chdir("..")

# %%
os.getcwd()
# Out:
# 'd:\\GitHub\\MLOps-Bootcamp\\Python-Prerequisite\\05-Modules'

# %% [markdown]
# ### Assignment 15: Handling Package Import Errors
#
# Write code that attempts to import a non-existent function from `mypackage` and gracefully handles the import error by printing an error message.

# %%
try:
    from module1 import subtraction
except ImportError:
    print("Error: The function does not exist.")
# Out:
# Error: The function does not exist.
